# %%
import attr
import os
import spacy
import re
import torch

import numpy as np
import pandas as pd

from annoy import AnnoyIndex
from cached_property import cached_property
from glob import glob
from tqdm import tqdm_notebook
from itertools import islice
from boltons.iterutils import chunked_iter
from datetime import datetime as dt

from sent_order.models import kt_regression as kt_reg

# %%
sent_encoder = torch.load(
    '../../plot-ordering/data/models/new/kt-reg/sent_encoder.68.bin',
    map_location={'cuda:0': 'cpu'}
)

# %%
nlp = spacy.load('en')
nlp.add_pipe(nlp.create_pipe('sentencizer'))

# %%
def clean_text(text):
    return re.sub('[\s]{2,}|\n', ' ', text.strip())

# %%
@attr.s
class Sentence:
    
    text = attr.ib()
        
    @cached_property
    def doc(self):
        return nlp(self.text, disable=['parser', 'tagger', 'ner'])
    
    def tokens(self):
        return [t.text for t in self.doc]
    
    def sent_order_variable(self):
        return kt_reg.Sentence(self.tokens()).variable()
    
    def embedding(self):
        x = self.sent_order_variable()
        return sent_encoder([x])[0].data.tolist()

# %%
@attr.s
class Segment:
    
    path = attr.ib()
    
    def text(self):
        with open(self.path) as fh:
            return clean_text(fh.read())
        
    @cached_property
    def doc(self):
        return nlp(self.text(), disable=['tokenizer', 'parser', 'tagger', 'ner'])
    
    @cached_property
    def paper_name(self):
        return self.path.split(os.sep)[-3]
    
    @cached_property
    def date(self):
        return dt.strptime(self.path.split(os.sep)[-2], '%m-%d-%Y')
    
    def sentence_texts(self):
        for sent in self.doc.sents:
            yield sent.text

# %%
@attr.s
class NewspaperCorpus:
    
    root = attr.ib()
    
    def paths(self):
        return glob(os.path.join(self.root, '**/*.txt'), recursive=True)
    
    def segments(self):
        for path in tqdm_notebook(self.paths()):
            yield Segment(path)
            
    def df_rows(self, skim=None):
        for segment in self.segments():
            for text in segment.sentence_texts():
                yield dict(paper_name=segment.paper_name, date=segment.date, text=text)

# %%
c = NewspaperCorpus('../data/kathy2012/newspapers2012/')

# %%
sent_db = pd.DataFrame(list(c.df_rows()))
# Out:
# HBox(children=(IntProgress(value=0, max=7437), HTML(value='')))

# %%
sent_db
# Out:
#              date               paper_name  \
# 0      2012-01-31       Ashland Daily Post
# 1      2012-01-31       Ashland Daily Post
# 2      2012-01-31       Ashland Daily Post
# 3      2012-01-31       Ashland Daily Post
# 4      2012-01-31       Ashland Daily Post
# 5      2012-01-31       Ashland Daily Post
# 6      2012-01-31       Ashland Daily Post
# 7      2012-01-31       Ashland Daily Post
# 8      2012-01-31       Ashland Daily Post
# 9      2012-01-31       Ashland Daily Post
# 10     2012-01-31       Ashland Daily Post
# 11     2012-01-31       Ashland Daily Post
# 12     2012-01-31       Ashland Daily Post
# 13     2012-01-31       Ashland Daily Post
# 14     2012-01-31       Ashland Daily Post
# 15     2012-01-31       Ashland Daily Post
# 16     2012-01-31       Ashland Daily Post
# 17     2012-01-31       Ashland Daily Post
# 18     2012-01-31       Ashland Daily Post
# 19     2012-01-31       Ashland Daily Post
# 20     2012-01-31       Ashland Daily Post
# 25      The commercial was the last in a race in which...
# 26      Perry and a super PAC supporting him spent the...
# 27      But it was the combina- tion of Romney ($1.3 m...
# 28      That was particularly so in the final few week...
# 29      ARSON SUSPECTED — A Crime Stoppers poster is s...
# ...                                                   ...
# 785581  The family would like to thank Oakwood Village...
# 785582  He was born in Knowlton on March 27, 1919, the...
# 785583  His parents emigrated to the Uniterd States fr...
# 785584  He learned to speak English in a one room scho...
# 785585  He graduated from Stevens Point High School an...
# 785586  Besides teaching he worked at Badger Ord- nanc...
# 785587  In 1948, he joined Oscar Mayer Co., where he r...
# 785588  John enjoyed hunting and fishing, bowling (he ...
# 785589  He enjoyed teaching Sun- day school and home B...
# 785590  John remained physically active all his life, ...
# 785591  He was still using his riding lawn mower six m...
# 785592  John also enjoyed travel, includ- ing trips in...
# 785593  But the most important thing to John was his f...
# 785594  He made every attempt to attend all family fun...
# 785595  After the death of his first wife, Doris, he m...
# 785596  He is survived by his wife, Irene; his childre...
# 785597  He was preceded in death by his wife, Doris; a...
# 785598  A funeral service will be held at 12 noon on W...
# 785599  Burial will follow at Lakeview Lutheran Cem- e...
# 785600  A visitation will be held from 10 a.m. until t...
# 785601  To view and sign this guestbook, please visit:...
# 785602  608) -249-8257 Ripp, Theresa M. CROSS PLAINS /...
# 785603  Theresa M. Ripp was born on April 15, 1914, to...
# 785604  She was married to Raymond P. Ripp for 55 year...
# 785605           She was a loving and very caring person.
# 785606  Theresa devoted her life to Ray and raising he...
# 785607  Her specialty was flower arranging and enterta...
# 785608  She held a life mem- bership in the Wisconsin ...
# 785609  Surviving her is her daughter, Clara (George) ...
# 785610                Her only surviving brother is Leon-
#
# [785611 rows x 3 columns]

# %%
sent_idx = AnnoyIndex(1000)

id_text = list(sent_db['text'].iteritems())

for chunk in chunked_iter(tqdm_notebook(id_text), 1000):
    
    ids, texts = zip(*chunk)
    
    x = [Sentence(t).sent_order_variable() for t in texts]
    x = sent_encoder(x)
    
    for i, v in zip(ids, x):
        sent_idx.add_item(i, v.data.tolist())
    
sent_idx.build(10)
# Out:
# HBox(children=(IntProgress(value=0, max=785611), HTML(value='')))
# True

# %%
def query(text, n=10):
    sent = Sentence(text)
    for ri in sent_idx.get_nns_by_vector(sent.embedding(), n):
        print(sent_db.iloc[ri].text, '\n')

# %%
query("This is wonderful.")
# Out:
# This is just so wonderful.”
#
# This is just so wonderful.”
#
# This is a great way to spend a cold winter evening.
#
# This is one of the characteristics that make our country great.
#
# This is a great opportunity for us today,’’ Walker said. ‘‘
#
# This is great research-based information about how to be successful with whatev- er the topic is.”
#
# This is a wonder- ful opportunity. “
#
# This is by far the most ambitious thing I’ve done in my career.
#
# This is a very good venue for local artists to show their work,” Lorber said. “
#
# This is all because we’re in the process of negotiating the permanent rule,’’ she said.

# %%
with open('../data/sent_db.json', 'w') as fh:
    print(sent_db.to_json(orient='records'), file=fh)

# %%
sent_idx.save('../data/sent_idx.bin')
# Out:
# True
